# %%
# !git clone https://github.com/sinh2206/Object_Detection.git
# Out:
# Cloning into 'Object_Detection'...
# remote: Enumerating objects: 10058, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 10058 (delta 0), reused 0 (delta 0), pack-reused 10057 (from 3)
# Receiving objects: 100% (10058/10058), 1.06 GiB | 28.49 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Updating files: 100% (10035/10035), done.

# %%
# %cd Object_Detection
# !ls
# Out:
# /content/Object_Detection
# LICENSE			   predict.py	README.md	  utils
# object-dectection-2.ipynb  public	requirements.txt
# object_detection.ipynb	   __pycache__	train.py

# %%
# %pip install -r requirements.txt

# %%
# !python train.py \
  --train_data ./public/annotations/train.json \
  --val_data ./public/annotations/val.json \
  --image_dir ./public/train/images \
  --val_image_dir ./public/val/images \
  --checkpoint_dir ./models/
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 146MB/s]
# /content/Object_Detection/train.py:243: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp else None
# ...

# %%
# !python predict.py \
  --image_dir ./public/val1/images \
  --output val1_predictions.json \
  --model_path ./models/best.pth

# %%
# !python public/tools/evaluate_predictions.py \
  --ground_truth public/annotations1/val.json \
  --predictions val1_predictions.json \
  --output val1_score.json

# %%
# !python predict.py \
  --image_dir ./public/train1/images \
  --output train1_predictions.json \
  --model_path ./models/best.pth
# Out:
# Saved predictions for 800 images to train1_predictions.json

# %%
# !python public/tools/evaluate_predictions.py \
  --ground_truth public/annotations1/train.json \
  --predictions train1_predictions.json \
  --output train1_score.json
# Out:
# {
#   "mAP@0.5": 0.339094,
#   "performance_points": 10,
#   "iou_threshold": 0.5,
#   "num_ground_truth_boxes": 1121,
#   "num_predictions": 20677,
#   "micro_precision": 0.042995,
#   "micro_recall": 0.793042,
#   "per_class": {
#     "person": {
#       "ap": 0.446756,
#       "num_ground_truth": 602,
#       "num_predictions": 7139,
#       "true_positives": 477,
#       "false_positives": 6662,
#       "recall": 0.792359,
#       "precision": 0.066816
#     },
#     "car": {
#       "ap": 0.304294,
#       "num_ground_truth": 141,
#       "num_predictions": 2926,
#       "true_positives": 88,
#       "false_positives": 2838,
#       "recall": 0.624113,
#       "precision": 0.030075
#     },
#     "dog": {
#       "ap": 0.351058,
#       "num_ground_truth": 98,
#       "num_predictions": 1965,
#       "true_positives": 89,
#       "false_positives": 1876,
#       "recall": 0.908163,
#       "precision": 0.045293
#     },
#     "cat": {
#       "ap": 0.420094,
# ...
